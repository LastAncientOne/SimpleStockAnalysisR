# %% [markdown]
# # Simple Price Analysis Historical Data

# %%
# If do not have the packages install it
# install.packages('quantmod')
library(quantmod)
# Out:
# Loading required package: xts
# Loading required package: zoo
# Warning message:
# "package 'zoo' was built under R version 3.3.3"
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: TTR
# Version 0.4-0 included new data defaults. See ?getSymbols.

# %%
# If not have packages install, use this one to install
install.packages("quantmod", repos = "http://cran.us.r-project.org")
# Out:
# Installing package into 'C:/Users/Tin Hang/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# installing the source package 'quantmod'
#   There is a binary version available but the source version is later:
#          binary source needs_compilation
# quantmod 0.4-13 0.4-14             FALSE

# %%
# load the packages
library(quantmod)

# %%
getSymbols("AAPL")
# Out:
# 'getSymbols' currently uses auto.assign=TRUE by default, but will
# use auto.assign=FALSE in 0.5-0. You will still be able to use
# 'loadSymbols' to automatically load data. getOption("getSymbols.env")
# and getOption("getSymbols.auto.assign") will still be checked for
# alternate defaults.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.warning4.0"=FALSE). See ?getSymbols for details.
# [1] "AAPL"

# %%
# Count rows and columns
dim(AAPL)
# Out:
# [1] 3090    6

# %%
# Summary Stats
summary(AAPL)
# Out:
#      Index              AAPL.Open        AAPL.High         AAPL.Low
#  Min.   :2007-01-03   Min.   : 11.34   Min.   : 11.71   Min.   : 11.17
#  1st Qu.:2010-01-27   1st Qu.: 29.40   1st Qu.: 29.74   1st Qu.: 29.04
#  Median :2013-02-21   Median : 75.00   Median : 75.71   Median : 74.38
#  Mean   :2013-02-19   Mean   : 81.65   Mean   : 82.40   Mean   : 80.85
#  3rd Qu.:2016-03-16   3rd Qu.:115.64   3rd Qu.:116.51   3rd Qu.:114.19
#  Max.   :2019-04-11   Max.   :230.78   Max.   :233.47   Max.   :229.78
#    AAPL.Close      AAPL.Volume        AAPL.Adjusted
#  Min.   : 11.17   Min.   : 11475900   Min.   :  7.449
#  1st Qu.: 29.42   1st Qu.: 40667025   1st Qu.: 19.618
#  Median : 75.04   Median : 86385600   Median : 55.780
#  Mean   : 81.65   Mean   :114109542   Mean   : 72.108
#  3rd Qu.:115.31   3rd Qu.:154428225   3rd Qu.:109.174
#  Max.   :232.07   Max.   :843242400   Max.   :230.275

# %%
# Correlation
cor(AAPL)
# Out:
#               AAPL.Open  AAPL.High  AAPL.Low   AAPL.Close AAPL.Volume
# AAPL.Open      1.0000000  0.9998929  0.9998565  0.9997476 -0.6719192
# AAPL.High      0.9998929  1.0000000  0.9998274  0.9998776 -0.6701772
# AAPL.Low       0.9998565  0.9998274  1.0000000  0.9998849 -0.6750483
# AAPL.Close     0.9997476  0.9998776  0.9998849  1.0000000 -0.6727014
# AAPL.Volume   -0.6719192 -0.6701772 -0.6750483 -0.6727014  1.0000000
# AAPL.Adjusted  0.9931410  0.9933150  0.9933342  0.9934437 -0.6606175
#               AAPL.Adjusted
# AAPL.Open      0.9931410
# AAPL.High      0.9933150
# AAPL.Low       0.9933342
# AAPL.Close     0.9934437
# AAPL.Volume   -0.6606175
# AAPL.Adjusted  1.0000000

# %%
OpCl(AAPL) # Daily Percent change Open to Close
# Out:
#                OpCl.AAPL
# 2007-01-03 -2.885616e-02
# 2007-01-04  1.915526e-02
# 2007-01-05 -8.394532e-03
# 2007-01-08 -5.700326e-03
# 2007-01-09  7.079239e-02
# 2007-01-10  2.374666e-02
# 2007-01-11 -1.459172e-03
# 2007-01-12  3.171794e-04
# 2007-01-16  1.484113e-02
# 2007-01-17 -2.675283e-02
# 2007-01-18 -3.289901e-02
# 2007-01-19 -1.466659e-03
# 2007-01-22 -2.636300e-02
# 2007-01-23 -3.499592e-04
# 2007-01-24  2.308030e-04
# 2007-01-25 -9.872564e-03
# 2007-01-26 -1.985988e-02
# 2007-01-29 -4.171449e-03
# 2007-01-30 -1.018163e-02
# 2007-01-31  1.025220e-02
# 2007-02-01 -1.727936e-02
AAPL)
# Out:
#            AAPL.Open AAPL.High AAPL.Low AAPL.Close AAPL.Volume AAPL.Adjusted
# 2007-01-03  12.32714  12.36857 11.70000   11.97143   309579900      7.982585
# 2007-01-04  12.00714  12.27857 11.97429   12.23714   211815100      8.159763
# 2007-01-05  12.25286  12.31428 12.05714   12.15000   208685400      8.101658
# 2007-01-08  12.28000  12.36143 12.18286   12.21000   199276700      8.141665
# 2007-01-09  12.35000  13.28286 12.16429   13.22429   837324600      8.817995
# 2007-01-10  13.53571  13.97143 13.35000   13.85714   738220000      9.239983

# %%
# The last 6 rows
tail(AAPL)
# Out:
#            AAPL.Open AAPL.High AAPL.Low AAPL.Close AAPL.Volume AAPL.Adjusted
# 2019-04-04    194.79    196.37   193.14     195.69    19114300        195.69
# 2019-04-05    196.45    197.10   195.93     197.00    18526600        197.00
# 2019-04-08    196.42    200.23   196.34     200.10    25881700        200.10
# 2019-04-09    200.32    202.85   199.23     199.50    35768200        199.50
# 2019-04-10    198.68    200.74   198.18     200.62    21695300        200.62
# 2019-04-11    200.85    201.00   198.44     198.95    20900800        198.95

# %%
# Use particular columns
head(AAPL$AAPL.Adjusted)
# Out:
#            AAPL.Adjusted
# 2007-01-03      7.982585
# 2007-01-04      8.159763
# 2007-01-05      8.101658
# 2007-01-08      8.141665
# 2007-01-09      8.817995
# 2007-01-10      9.239983

# %%
AAPL$AAPL.Adjusted[1:2]
# Out:
#            AAPL.Adjusted
# 2007-01-03      7.982585
# 2007-01-04      8.159763

# %%
# [rows, columns]
AAPL[1:2, 1:3]
# Out:
#            AAPL.Open AAPL.High AAPL.Low
# 2007-01-03  12.32714  12.36857 11.70000
# 2007-01-04  12.00714  12.27857 11.97429

# %%
AAPL[1:5, 'AAPL.High']
# Out:
#            AAPL.High
# 2007-01-03  12.36857
# 2007-01-04  12.27857
# 2007-01-05  12.31428
# 2007-01-08  12.36143
# 2007-01-09  13.28286

# %%
# Rows & 2nd column
AAPL[1:5, 2]
# Out:
#            AAPL.High
# 2007-01-03  12.36857
# 2007-01-04  12.27857
# 2007-01-05  12.31428
# 2007-01-08  12.36143
# 2007-01-09  13.28286

# %%
AAPL$AAPL.Close[1:5]
# Out:
#            AAPL.Close
# 2007-01-03   11.97143
# 2007-01-04   12.23714
# 2007-01-05   12.15000
# 2007-01-08   12.21000
# 2007-01-09   13.22429

# %%
# Create Daily Returns
# Simple way is use Delt function mode from quantmod
Delt(AAPL$AAPL.Adjusted)
# Out:
#            Delt.1.arithmetic
# 2007-01-03                NA
# 2007-01-04      2.219557e-02
# 2007-01-05     -7.120918e-03
# 2007-01-08      4.938125e-03
# 2007-01-09      8.307023e-02
# 2007-01-10      4.785532e-02
# 2007-01-11     -1.237113e-02
# 2007-01-12     -1.231745e-02
# 2007-01-16      2.621014e-02
# 2007-01-17     -2.214193e-02
# 2007-01-18     -6.192728e-02
# 2007-01-19     -6.399483e-03
# 2007-01-22     -1.932210e-02
# 2007-01-23     -1.255896e-02
# 2007-01-24      1.166891e-02
# 2007-01-25     -5.190442e-03
# 2007-01-26     -1.008694e-02
# 2007-01-29      6.558882e-03
# 2007-01-30     -4.538116e-03
# 2007-01-31      2.103743e-03
# 2007-02-01     -1.154776e-02
# 2007-02-02      1.180606e-04
# 2007-02-05     -9.557444e-03
# 2007-02-06      2.501776e-03
# 2007-02-07      2.376719e-02
# 2007-02-08      3.477756e-04
# 2007-02-09     -3.376636e-02
# 2007-02-12      1.933474e-02
# 2007-02-13     -2.120596e-03
# 2007-02-14      7.083634e-03
# 2007-02-15     -1.054708e-03
# ...

# %%
# Another way to calculate daily returns
# This log returns
ret <- diff(log(AAPL$AAPL.Adjusted))
ret
# Out:
#            AAPL.Adjusted
# 2007-01-03            NA
# 2007-01-04  2.195283e-02
# 2007-01-05 -7.146392e-03
# 2007-01-08  4.925972e-03
# 2007-01-09  7.979982e-02
# 2007-01-10  4.674553e-02
# 2007-01-11 -1.244829e-02
# 2007-01-12 -1.239393e-02
# 2007-01-16  2.587254e-02
# 2007-01-17 -2.239075e-02
# 2007-01-18 -6.392780e-02
# 2007-01-19 -6.420047e-03
# 2007-01-22 -1.951121e-02
# 2007-01-23 -1.263849e-02
# 2007-01-24  1.160135e-02
# 2007-01-25 -5.203959e-03
# 2007-01-26 -1.013816e-02
# 2007-01-29  6.537466e-03
# 2007-01-30 -4.548444e-03
# 2007-01-31  2.101533e-03
# 2007-02-01 -1.161496e-02
# 2007-02-02  1.180536e-04
# 2007-02-05 -9.603409e-03
# 2007-02-06  2.498651e-03
# 2007-02-07  2.348915e-02
# 2007-02-08  3.477151e-04
# 2007-02-09 -3.434961e-02
# 2007-02-12  1.915019e-02
# 2007-02-13 -2.122848e-03
# 2007-02-14  7.058663e-03
# 2007-02-15 -1.055265e-03
# 2007-02-16 -4.469682e-03
# 2007-02-20  1.253450e-02
# 2007-02-21  3.769733e-02
# 2007-02-22  3.469329e-03
# 2007-02-23 -4.927852e-03
# ...

# %%
# This simple returns
n = length(AAPL$AAPL.Adjusted)

simple_ret <- diff(AAPL$AAPL.Adjusted)/AAPL$AAPL.Adjusted[1:(n-1)] 
simple_ret
# Out:
#            AAPL.Adjusted
# 2007-01-03            NA
# 2007-01-04  2.171362e-02
# 2007-01-05 -7.171989e-03
# 2007-01-08  4.913860e-03
# 2007-01-09  7.669884e-02
# 2007-01-10  4.566978e-02
# 2007-01-11 -1.252609e-02
# 2007-01-12 -1.247106e-02
# 2007-01-16  2.554071e-02
# 2007-01-17 -2.264330e-02
# 2007-01-18 -6.601543e-02
# 2007-01-19 -6.440700e-03
# 2007-01-22 -1.970280e-02
# 2007-01-23 -1.271869e-02
# 2007-01-24  1.153432e-02
# 2007-01-25 -5.217523e-03
# 2007-01-26 -1.018973e-02
# 2007-01-29  6.516144e-03
# 2007-01-30 -4.558804e-03
# 2007-01-31  2.099326e-03
# 2007-02-01 -1.168267e-02
# 2007-02-02  1.180467e-04
# 2007-02-05 -9.649670e-03
# 2007-02-06  2.495532e-03
# 2007-02-07  2.321542e-02
# 2007-02-08  3.476547e-04
# 2007-02-09 -3.494637e-02
# 2007-02-12  1.896799e-02
# 2007-02-13 -2.125103e-03
# 2007-02-14  7.033809e-03
# 2007-02-15 -1.055822e-03
# 2007-02-16 -4.479686e-03
# 2007-02-20  1.245627e-02
# 2007-02-21  3.699563e-02
# 2007-02-22  3.463318e-03
# 2007-02-23 -4.940014e-03
# ...

# %%
# Create a dataframe with dates and Adj Price
aapl_prices <- AAPL[, "AAPL.Adjusted", drop = FALSE]
rownames(aapl_prices) <- AAPL$Date
head(aapl_prices)
# Out:
#            AAPL.Adjusted
# 2007-01-03      7.982585
# 2007-01-04      8.159763
# 2007-01-05      8.101658
# 2007-01-08      8.141665
# 2007-01-09      8.817995
# 2007-01-10      9.239983
